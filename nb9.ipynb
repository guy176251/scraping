# %%
# %%html
# <script>
#     // AUTORUN ALL CELLS ON NOTEBOOK-LOAD!
#     require(
#         ['base/js/namespace', 'jquery'],
#         function(jupyter, $) {
#             $(jupyter.events).on("kernel_ready.Kernel", function () {
#                 console.log("Auto-running all cells-below...");
#                 jupyter.actions.call('jupyter-notebook:run-all-cells-below');
#                 jupyter.actions.call('jupyter-notebook:save-notebook');
#             });
#         }
#     );
# </script>
# Out:
# <script>
#     // AUTORUN ALL CELLS ON NOTEBOOK-LOAD!
#     require(
#         ['base/js/namespace', 'jquery'],
#         function(jupyter, $) {
#             $(jupyter.events).on("kernel_ready.Kernel", function () {
#                 console.log("Auto-running all cells-below...");
#                 jupyter.actions.call('jupyter-notebook:run-all-cells-below');
#                 jupyter.actions.call('jupyter-notebook:save-notebook');
#             });
#         }
#     );
# </script>

# %%
from scraping import *
import pandas as pd

# %%
# Ramon Dekkers Record Table

# %%
doc = lxmler('https://en.wikipedia.org/wiki/Ramon_Dekkers')
table = first_elem(doc, 'table.toccolours table.wikitable')

# %%
raw = [row for tr in all_elems(table, 'tr')
       if (row := [td.text_content().replace('\n', '') for td in all_elems(tr, 'td')])]

record = pd.DataFrame(raw[1:], columns=raw[0])
record
# Out:
#           Date Result               Opponent  \
# 0   2006-05-13   Loss             Joerie Mes
# 1   2005-07-20    Win           Duane Ludwig
# 2   2001-03-18    Win        Marino Deflorin
# 3   2000-11-01   Draw           Akeomi Nitta
# 4   2000-01-25   Loss   Takayuki Kohiruimaki
# ..         ...    ...                    ...
# 75  1987-03-21   Loss            Richard Nam
# 76        1986    Win               L. Cairo
# 77  1986-10-05    Win                   Boyd
# 78  1986-02-02    Win               Onbekend
# 79        1986    Win               Masseurs
#
#                                      Event                   Location  \
# 0   K-1 World Grand Prix 2006 in Amsterdam     Amsterdam, Netherlands
# 1    K-1 World MAX 2005 Final, Super Fight            Yokohama, Japan
# 2      2 Hot 2 Handle III: Simply The Best     Rotterdam, Netherlands
# 3                           K-1 J-MAX 2000               Tokyo, Japan
# ...

# %%
losses = record[record.Result == 'Loss']
losses[losses.Event == 'Lumpinee Stadium']
# Out:
#           Date Result                   Opponent             Event  \
# 20  1995-11-27   Loss       Teerapong Sitgolyoot  Lumpinee Stadium
# 22        1995   Loss           Cherry S. Wanich  Lumpinee Stadium
# 30        1994   Loss       Superlek Sorn E-Sarn  Lumpinee Stadium
# 46  1991-11-26   Loss     Sakmongkol Sithchuchok  Lumpinee Stadium
# 49  1991-09-03   Loss    Sangtiennoi Sor.Rungroj  Lumpinee Stadium
# 51        1991   Loss       Superlek Sorn E-Sarn  Lumpinee Stadium
# 56  1990-11-27   Loss          Issara Sakkreerin  Lumpinee Stadium
# 58  1990-04-20   Loss   Namphon Nongkee Pahuyuth  Lumpinee Stadium
#
#              Location                Method Round  Time Record
# 20  Bangkok, Thailand              Decision     5  3:00
# 22  Bangkok, Thailand              Decision     5  3:00
# 30  Bangkok, Thailand  Decision (Unanimous)     5  3:00
# 46  Bangkok, Thailand  Decision (Unanimous)     5  3:00
# 49  Bangkok, Thailand  Decision (Unanimous)     5  3:00
# ...

# %%
wins = record[record.Result == 'Win']
wins[wins.Event == 'Lumpinee Stadium']
# Out:
#           Date Result                   Opponent             Event  \
# 50  1991-08-06    Win   Coban Lookchaomaesaitong  Lumpinee Stadium
# 53        1991    Win        Sombat Sor Thanikul  Lumpinee Stadium
# 57  1990-08-31    Win       Superlek Sorn E-Sarn  Lumpinee Stadium
#
#              Location                Method Round  Time Record
# 50  Bangkok, Thailand      KO (Right cross)     1
# 53  Bangkok, Thailand  Decision (Unanimous)     5  3:00
# 57  Bangkok, Thailand  Decision (Unanimous)     5  3:00

# %%
losses[~losses.Method.str.contains('KO')]
# Out:
#           Date Result                     Opponent  \
# 0   2006-05-13   Loss                   Joerie Mes
# 6   1998-05-23   Loss           Abdelkader Tarzati
# 8   1997-11-22   Loss                    Dany Bill
# 10  1997-07-13   Loss   Namkabuan Nongkeeprawayuth
# 14  1997-02-27   Loss                 Jerry Morris
# 15  1996-12-05   Loss            Jomhod Kiatadisak
# 17        1996   Loss          Francois Pennacchio
# 19  1995-12-05   Loss               Den Muangsurin
# 20  1995-11-27   Loss         Teerapong Sitgolyoot
# 22        1995   Loss             Cherry S. Wanich
# 24  1995-04-08   Loss         Orono Por Muang-Ubol
# 29        1994   Loss        Saimai Chor Suanatant
# 30        1994   Loss         Superlek Sorn E-Sarn
# 31        1994   Loss                  Dida Diafat
# 34  1993-12-04   Loss     Jaroenthong Kiatbangchon
# 36     1993-10   Loss               Den Muangsurin
# 39  1993-04-26   Loss         Orono Por Muang-Ubol
# ...
